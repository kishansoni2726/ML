# %%
import tensorflow as tf
from tensorflow import keras
from PIL import Image

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images , train_labels) , (test_images , test_labels) = fashion_mnist.load_data()

# %%
print(len(train_labels),len(test_labels),len(train_images),len(test_images))
# Out:
# 60000 10000 60000 10000

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128,activation=tf.nn.relu),
                          keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),loss='sparse_categorical_crossentropy')

# %%
model.fit(train_images,train_labels,epochs= 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.8927
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7000
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5983
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5535
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5361

# %%
test_loss = model.evaluate(test_images,test_labels)
# prediction = model.predict("https://i1.adis.ws/i/drmartens/11821006.80.jpg?$medium$")
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5730
