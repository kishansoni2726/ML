# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import sgd
import numpy as np

# Describing that model is in sequential manner
model = keras.Sequential([keras.layers.Dense(units = 1,input_shape = [1])])

# %%
# Compile model for use
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
# Giving Data for optimization
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
# Giving values to Model
model.fit(xs,ys,epochs=1000)

# %%
# Predicting value of y for given input of X 
# if X=11 than Y = 20.99(21)
# Y = 2X - 1
# 21 = 2(11) - 1
print(model.predict([11.0]))
# Out:
# [[20.999985]]
